# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips  # dataset about tips given by ppl
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# seaborn gives better result than matplotlib......both are diff libraries

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.histplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips["total_bill"])
# Out:
# C:\Users\Mahadevan\AppData\Local\Temp\ipykernel_10188\1984207902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#if we don't want that above line
sns.distplot(tips["total_bill"],kde=False)
# Out:
# C:\Users\Mahadevan\AppData\Local\Temp\ipykernel_10188\1683979588.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"],kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips["total_bill"],kde=False,bins=30) #bins makes width smaller
# Out:
# C:\Users\Mahadevan\AppData\Local\Temp\ipykernel_10188\4174845964.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"],kde=False,bins=30) #bins makes width smaller
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(x=tips.total_bill,y=tips.tip) #represented in scatter plot
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips, hue="smoker")

#hue is a paramter used to diffrentiate diff types of data

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips, hue="size")

# %%
tips #smoker and size are columns in tips dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips, style="smoker")

#size is for diff markers 

#hue represents colurs

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips, style="smoker",hue="time")

#using both style and hue

# %%
sns.catplot(x="day",y="total_bill",data=tips) #catplot is catagorical plot

# %%
sns.barplot(x="day",y="total_bill",data=tips) #barplot is bar graph...that line is just for representation
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip)

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips,kind="reg")

#reg is regresion line (line helps to understand the relationship between the feature)

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips,kind="hex")

#data become hexagon

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips,kind="kde")

#lot of use cases in metrological department (weather)

#center density is more as the waves grows bigger it decreases and it eventually stops

# %%
#pairplot: it will plot all the pairwise relationship of the dataframe

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips) #all pairplot and understandings in one view

# %%
sns.pairplot(tips,hue="sex")

#here we are having distributions for male and female

# %%
sns.pairplot(tips,hue="smoker")

# %%
sns.pairplot(tips,hue="smoker",palette="coolwarm")

#palette makes the colur dim and more colours

# %%
#boxplot is to know outliers
#1,2,3,4,5,100 >> extreme data are ouliers (1,2 and suddenly 100 came)
#for each day give me outlier for total bill

sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette="rainbow")

#now it gives rainbow colours
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,palette="rainbow",orient="h")

#orient is applicable only to whole data for it's outlayer
# Out:
# <Axes: >

# %%
#correlation(used only for numerical not for string) is to understand the relationship between 
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_num=tips[["total_bill","tip","size"]]
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(tips_num.corr(),annot=True) #we are making the output in a more understandable way

#visually appling way
# Out:
# <Axes: >

# %%
sns.heatmap(tips_num.corr(),annot=True,cmap="coolwarm") #colours represented in coolwarm term
# Out:
# <Axes: >

# %%
sns.countplot(x="sex",data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x="total_bill",y="tip",data=tips) #NOTE no quote for data=tips or else error

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,aspect=4) #the graph squuese and inc acc to aspect number

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,aspect=1)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,aspect=1,height=2) #height also can be changed

# %%
sns.catplot(x="day",y="tip",data=tips,kind="swarm") 

#catogorical plot in swarm plot
# Out:
# C:\Users\Mahadevan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#pie chart

import matplotlib.pyplot as plt
langs=["c","python","java"]
students=[20,100,40]
plt.pie(students,labels=langs)
plt.title("pie chart")
plt.show()

# %%
import matplotlib.pyplot as plt
langs=["c","python","java"]
students=[20,100,40]
plt.pie(students,labels=langs,autopct="%1.1f%%") #to represent values in percentage
plt.title("pie chart")
plt.show()

# %%
my_explode=(0.0,1.0,0) #give only one 0 more than one zero it gives error
import matplotlib.pyplot as plt
langs=["c","python","java"]
students=[20,100,40]
plt.pie(students,labels=langs,autopct="%1.1f%%",explode=my_explode, shadow=True) 
plt.title("pie chart")
plt.show()

# %% [markdown]
# my_explode=(0.0,1.0,0) was too many space between them so in next code we reduced to (0.0,0.1,0) in order to remove too many space between them

# %%
my_explode=(0.0,0.1,0) #give only one 0 more than one zero it gives error
import matplotlib.pyplot as plt
langs=["c","python","java"]
students=[20,100,40]
plt.pie(students,labels=langs,autopct="%1.1f%%",explode=my_explode, shadow=True) 
plt.title("pie chart")
plt.show()

# %%
import numpy as np

data=np.random.randn(1000)
data
# Out:
# array([-2.87265738e-01, -8.70931310e-01,  3.65213283e-02,  2.14158420e-01,
#        -9.93922915e-01,  8.67764888e-02, -7.05992532e-01,  2.60542318e-01,
#        -5.43083142e-01,  4.94558850e-01,  4.00827426e-01, -6.42012021e-01,
#        -9.82484874e-01,  1.06958384e+00,  1.95512475e-01, -9.38695598e-02,
#        -8.89379731e-01, -1.56988753e+00, -9.60929560e-01,  4.97032975e-01,
#        -4.36581082e-01, -5.05448035e-02,  6.28999399e-01, -1.53438584e+00,
#        -7.61127635e-01,  1.10550224e+00, -1.25688217e+00, -4.33612376e-02,
#        -1.00137805e+00, -1.91633617e+00,  1.31540878e+00, -6.30129496e-01,
#         9.97277081e-01,  2.04571755e-01,  7.52034769e-01,  1.14211512e+00,
#         1.17988835e+00, -3.78191740e-02, -1.26613959e+00,  8.74593976e-01,
#         1.22701918e+00, -4.86220971e-01, -1.52398540e+00,  8.95329563e-01,
#        -6.73977414e-01, -2.00732417e-01, -1.38039999e+00,  7.20439725e-01,
# ...

# %%
data=np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
data.boxplot(column="Balance") #code is crt maybe some error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 data.boxplot(column="Balance")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'boxplot'

# %%
plt.violinplot(data["Balance"])#code is crt maybe some error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 plt.violinplot(data["Balance"])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
