# %%
import pandas as pd
data=pd.read_csv("currency.csv")
data
# Out:
#     Code Symbol                      Name
# 0    AED    د.إ    United Arab Emirates d
# 1    AFN      ؋            Afghan afghani
# 2    ALL      L              Albanian lek
# 3    AMD    AMD             Armenian dram
# 4    ANG      ƒ  Netherlands Antillean gu
# ..   ...    ...                       ...
# 158  XOF    CFA    West African CFA franc
# 159  XPF     Fr                 CFP franc
# 160  YER      ﷼               Yemeni rial
# 161  ZAR      R        South African rand
# 162  ZMW     ZK            Zambian kwacha
#
# [163 rows x 3 columns]

# %%
import pandas as pd
data=pd.read_csv("industry.csv")
data
# Out:
#                          Industry
# 0              Accounting/Finance
# 1    Advertising/Public Relations
# 2              Aerospace/Aviation
# 3   Arts/Entertainment/Publishing
# 4                      Automotive
# 5                Banking/Mortgage
# 6            Business Development
# 7            Business Opportunity
# 8         Clerical/Administrative
# 9         Construction/Facilities
# 10                 Consumer Goods
# 11               Customer Service
# 12             Education/Training
# 13               Energy/Utilities
# 14                    Engineering
# 15            Government/Military
# 16                          Green
# 17                     Healthcare
# 18             Hospitality/Travel
# 19                Human Resources
# 20       Installation/Maintenance
# 21                      Insurance
# 22                       Internet
# 23                Job Search Aids
# 24       Law Enforcement/Security
# 25                          Legal
# ...

# %%
import pandas as pd
data=pd.read_csv("currency.csv")
data
# Out:
#     Code Symbol                      Name
# 0    AED    د.إ    United Arab Emirates d
# 1    AFN      ؋            Afghan afghani
# 2    ALL      L              Albanian lek
# 3    AMD    AMD             Armenian dram
# 4    ANG      ƒ  Netherlands Antillean gu
# ..   ...    ...                       ...
# 158  XOF    CFA    West African CFA franc
# 159  XPF     Fr                 CFP franc
# 160  YER      ﷼               Yemeni rial
# 161  ZAR      R        South African rand
# 162  ZMW     ZK            Zambian kwacha
#
# [163 rows x 3 columns]

# %%
import pandas as pd
data=pd.read_csv("currency.csv", header=None)
data
# Out:
#         0       1                       2
# 0    Code  Symbol                    Name
# 1     AED     د.إ  United Arab Emirates d
# 2     AFN       ؋          Afghan afghani
# 3     ALL       L            Albanian lek
# 4     AMD     AMD           Armenian dram
# ..    ...     ...                     ...
# 159   XOF     CFA  West African CFA franc
# 160   XPF      Fr               CFP franc
# 161   YER       ﷼             Yemeni rial
# 162   ZAR       R      South African rand
# 163   ZMW      ZK          Zambian kwacha
#
# [164 rows x 3 columns]

# %%
import pandas as pd
data=pd.read_csv("currency.csv")
data
# Out:
#     Code Symbol                      Name
# 0    AED    د.إ    United Arab Emirates d
# 1    AFN      ؋            Afghan afghani
# 2    ALL      L              Albanian lek
# 3    AMD    AMD             Armenian dram
# 4    ANG      ƒ  Netherlands Antillean gu
# ..   ...    ...                       ...
# 158  XOF    CFA    West African CFA franc
# 159  XPF     Fr                 CFP franc
# 160  YER      ﷼               Yemeni rial
# 161  ZAR      R        South African rand
# 162  ZMW     ZK            Zambian kwacha
#
# [163 rows x 3 columns]

# %%
#first row will be treated as column name in pandas so put header=None (now it is treated as row itself)

# %%
# to fetch a perticular column in data
import pandas as pd
data=pd.read_csv("currency.csv", usecols=["Code"])
data
# Out:
#     Code
# 0    AED
# 1    AFN
# 2    ALL
# 3    AMD
# 4    ANG
# ..   ...
# 158  XOF
# 159  XPF
# 160  YER
# 161  ZAR
# 162  ZMW
#
# [163 rows x 1 columns]

# %%
import pandas as pd
data=pd.read_csv("currency.csv", usecols=["Code","Symbol"])
data
# Out:
#     Code Symbol
# 0    AED    د.إ
# 1    AFN      ؋
# 2    ALL      L
# 3    AMD    AMD
# 4    ANG      ƒ
# ..   ...    ...
# 158  XOF    CFA
# 159  XPF     Fr
# 160  YER      ﷼
# 161  ZAR      R
# 162  ZMW     ZK
#
# [163 rows x 2 columns]

# %%
#it skips the rows
import pandas as pd
data=pd.read_csv("currency.csv",skiprows=3)
data
# Out:
#      ALL    L              Albanian lek
# 0    AMD  AMD             Armenian dram
# 1    ANG    ƒ  Netherlands Antillean gu
# 2    AOA   Kz            Angolan kwanza
# 3    ARS    $            Argentine peso
# 4    AUD    $         Australian dollar
# ..   ...  ...                       ...
# 155  XOF  CFA    West African CFA franc
# 156  XPF   Fr                 CFP franc
# 157  YER    ﷼               Yemeni rial
# 158  ZAR    R        South African rand
# 159  ZMW   ZK            Zambian kwacha
#
# [160 rows x 3 columns]

# %%
data
# Out:
#      ALL    L              Albanian lek
# 0    AMD  AMD             Armenian dram
# 1    ANG    ƒ  Netherlands Antillean gu
# 2    AOA   Kz            Angolan kwanza
# 3    ARS    $            Argentine peso
# 4    AUD    $         Australian dollar
# ..   ...  ...                       ...
# 155  XOF  CFA    West African CFA franc
# 156  XPF   Fr                 CFP franc
# 157  YER    ﷼               Yemeni rial
# 158  ZAR    R        South African rand
# 159  ZMW   ZK            Zambian kwacha
#
# [160 rows x 3 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#data structure >> series, dataframe
#series >1 dimentional in nature
#dataframe >2 dimentional in nature , multiple series constitute to form a dataframe

# %%
import pandas as pd
data=pd.read_csv("currency.csv")
data
# Out:
#     Code Symbol                      Name
# 0    AED    د.إ    United Arab Emirates d
# 1    AFN      ؋            Afghan afghani
# 2    ALL      L              Albanian lek
# 3    AMD    AMD             Armenian dram
# 4    ANG      ƒ  Netherlands Antillean gu
# ..   ...    ...                       ...
# 158  XOF    CFA    West African CFA franc
# 159  XPF     Fr                 CFP franc
# 160  YER      ﷼               Yemeni rial
# 161  ZAR      R        South African rand
# 162  ZMW     ZK            Zambian kwacha
#
# [163 rows x 3 columns]

# %%
data.head(1) #can specify how many no.of header we want (default is 5)
# Out:
#   Code Symbol                    Name
# 0  AED    د.إ  United Arab Emirates d

# %%
data.tail(5) #last 5 rows
# Out:
#     Code Symbol                    Name
# 158  XOF    CFA  West African CFA franc
# 159  XPF     Fr               CFP franc
# 160  YER      ﷼             Yemeni rial
# 161  ZAR      R      South African rand
# 162  ZMW     ZK          Zambian kwacha

# %%
#to see random row
data.sample(2)
# Out:
#     Code Symbol                     Name
# 138  TJS     ЅМ       Tajikistani somoni
# 24   BYR     Br  Belarusian ruble (old)'

# %%
#to see no. of column
data.columns
# Out:
# Index(['Code', 'Symbol', 'Name'], dtype='object')

# %%
list(data.columns)
# Out:
# ['Code', 'Symbol', 'Name']

# %%
data.info() #to know the int.float or obj(data type) #string is identified as object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Code    163 non-null    object
#  1   Symbol  163 non-null    object
#  2   Name    163 non-null    object
# dtypes: object(3)
# memory usage: 3.9+ KB

# %%
data.shape
# Out:
# (163, 3)

# %%
data.Code
# Out:
# 0      AED
# 1      AFN
# 2      ALL
# 3      AMD
# 4      ANG
#       ...
# 158    XOF
# 159    XPF
# 160    YER
# 161    ZAR
# 162    ZMW
# Name: Code, Length: 163, dtype: object

# %%
data['Symbol']  #usally use this way
# Out:
# 0      د.إ
# 1        ؋
# 2        L
# 3      AMD
# 4        ƒ
#       ...
# 158    CFA
# 159     Fr
# 160      ﷼
# 161      R
# 162     ZK
# Name: Symbol, Length: 163, dtype: object

# %%
type(data['Code']) #data frame made up of series
# Out:
# pandas.core.series.Series

# %%
data['Name']
# Out:
# 0        United Arab Emirates d
# 1                Afghan afghani
# 2                  Albanian lek
# 3                 Armenian dram
# 4      Netherlands Antillean gu
#                  ...
# 158      West African CFA franc
# 159                   CFP franc
# 160                 Yemeni rial
# 161          South African rand
# 162              Zambian kwacha
# Name: Name, Length: 163, dtype: object

# %%
list(data['Name'])  #to remove the index
# Out:
# ['United Arab Emirates d',
#  'Afghan afghani',
#  'Albanian lek',
#  'Armenian dram',
#  'Netherlands Antillean gu',
#  'Angolan kwanza',
#  'Argentine peso',
#  'Australian dollar',
#  'Aruban florin',
#  'Azerbaijani manat',
#  'Bosnia and Herzegovina ',
#  'Barbadian dollar',
#  'Bangladeshi taka',
#  'Bulgarian lev',
#  'Bahraini dinar',
#  'Burundian franc',
#  'Bermudian dollar',
#  'Brunei dollar',
#  'Bolivian boliviano',
#  'Brazilian real',
#  'Bahamian dollar',
#  'Bitcoin',
#  'Bhutanese ngultrum',
#  'Botswana pula',
#  "Belarusian ruble (old)'",
#  'Belarusian ruble',
#  'Belize dollar',
#  'Canadian dollar',
#  'Congolese franc',
#  'Swiss franc',
#  'Chilean peso',
#  'Chinese yuan',
#  'Colombian peso',
#  'Costa Rican colón',
#  "Cuban convertible peso')",
#  'Cuban peso',
#  'Cape Verdean escudo',
#  'Czech koruna',
#  'Djiboutian franc',
#  'Danish krone',
#  'Dominican peso',
#  'Algerian dinar',
#  'Egyptian pound',
#  'Eritrean nakfa',
#  'Ethiopian birr',
# ...

# %%
pd.Series([2,3,4]) #capital S
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64

# %%
type(pd.Series([2,3,4]))
# Out:
# pandas.core.series.Series

# %%
pd.Series([2,3,4],index=[100,"ajay",2]) # we can convert the index to customized index
# Out:
# 100     2
# ajay    3
# 2       4
# dtype: int64

# %%
pd.DataFrame(pd.Series([2,3,4],index=[100,"ajay",2]))
# Out:
#       0
# 100   2
# ajay  3
# 2     4

# %%
d=pd.DataFrame(pd.Series([2,3,4],index=[100,"ajay",2]))
d
# Out:
#       0
# 100   2
# ajay  3
# 2     4

# %%
#if i don't want that column name to be 0
d.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
d.columns=["anwesha"] #we have changed here
d
# Out:
#       anwesha
# 100         2
# ajay        3
# 2           4

# %%
d[1]="anuj"  #added new column
d
# Out:
#       anwesha     1
# 100         2  anuj
# ajay        3  anuj
# 2           4  anuj

# %%
# to renmae both column
d.columns=["tr_id","name"]
d
# Out:
#       tr_id  name
# 100       2  anuj
# ajay      3  anuj
# 2         4  anuj

# %%
d.reset_index() #100,ajay and 2 will be a column and new index will be inserted
# Out:
#   index  tr_id  name
# 0   100      2  anuj
# 1  ajay      3  anuj
# 2     2      4  anuj

# %%
d #but the original data frame have not been modified that rese_index() is temperory
# Out:
#       tr_id  name
# 100       2  anuj
# ajay      3  anuj
# 2         4  anuj

# %%
d.reset_index(drop=True)
d#drops old index
# Out:
#       tr_id  name
# 100       2  anuj
# ajay      3  anuj
# 2         4  anuj

# %%
#to make the changes permanent 
#(inplace=True)
d.reset_index(drop=True,inplace=True)
d
# Out:
#    tr_id  name
# 0      2  anuj
# 1      3  anuj
# 2      4  anuj

# %%
data.head()
# Out:
#   Code Symbol                      Name
# 0  AED    د.إ    United Arab Emirates d
# 1  AFN      ؋            Afghan afghani
# 2  ALL      L              Albanian lek
# 3  AMD    AMD             Armenian dram
# 4  ANG      ƒ  Netherlands Antillean gu

# %%
data[["Code","Name"]]  #fro more than one data frame use 2 brackets
# Out:
#     Code                      Name
# 0    AED    United Arab Emirates d
# 1    AFN            Afghan afghani
# 2    ALL              Albanian lek
# 3    AMD             Armenian dram
# 4    ANG  Netherlands Antillean gu
# ..   ...                       ...
# 158  XOF    West African CFA franc
# 159  XPF                 CFP franc
# 160  YER               Yemeni rial
# 161  ZAR        South African rand
# 162  ZMW            Zambian kwacha
#
# [163 rows x 2 columns]

# %% [markdown]
# to read excel file

# %%
pd.read_excel("file_example_XLSX_50.xlsx")
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
#every functions used in csv file can also be acessed in this excel files

# %%
# to read github file

# %%
pd.read_csv("https://github.com//eduCBA//name-of-the-projectgoes-here.csv")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 pd.read_csv("https://github.com//eduCBA//name-of-the-projectgoes-here.csv")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
#same functions used in csv and excel can also be used for this github repository

# %%
# data3.to_csv("test.csv",index=False") 
#all the datas in github repository is saved in test csv file in local files

# %%
import pandas as pd

url = "https://www.basketball-reference.com/"
tables = pd.read_html(url)

# Now, you can access the tables as needed
for table in tables:
    print(table)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[88], line 4
#       1 import pandas as pd
#       3 url = "https://www.basketball-reference.com/"
# ----> 4 tables = pd.read_html(url)
#       6 # Now, you can access the tables as needed
#       7 for table in tables:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
# !pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 54.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd
import lxml
url = "https://www.basketball-reference.com/"        #use diff jupyter to run this code
tables = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[92], line 4
#       2 import lxml
#       3 url = "https://www.basketball-reference.com/"        #use diff jupyter to run this code
# ----> 4 tables = pd.read_html(url)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
#df4.to_csv("players.csv", index=False) # this is how u should store html files in local computer
